# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitk15/ml_series/blob/main/02_Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('Salary_Data.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# # Split train and test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)

# %% [markdown]
# # Create Model

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #Validate

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [9312.57512673]
# 26780.09915062818

# %%
#Salary=reg.coef_×YearsExperience+reg.intercept_
y = 9312.57512673 * 12 + 26780.09915062818
y
# Out:
# 138531.00067138817

# %%
reg.predict([[12]])
# Out:
# array([138531.00067138])

# %% [markdown]
# #Visualise Predict values

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title("Years of Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, reg.predict(X_train), color='green')
plt.title("Years of Experience vs Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')
